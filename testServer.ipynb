# %%
from fastapi import FastAPI, HTTPException
from fastapi.responses import FileResponse, HTMLResponse
import csv
import pandas as pd
app = FastAPI()

@app.get("/", response_class=HTMLResponse)
async def read_root():
    try:
        return FileResponse("index.html")
    except FileNotFoundError:
        raise HTTPException(status_code=404, detail="File not found")

@app.get("/sex", response_class=HTMLResponse)
async def read_func():
    try:
        return FileResponse("revenue.html")
    except FileNotFoundError:
        raise HTTPException(status_code=404, detail="File not found")

        
#when the courses are launched, Remove this dist entirely, No need to keep trash. 

@app.get("/dist/index.html", response_class=HTMLResponse)
async def read_func():
    try:
        return FileResponse("./dist/index.html")
    except FileNotFoundError:
        raise HTTPException(status_code=404, detail="File not found")

@app.get("/dist/script.js")
async def read_func():
    try:
        return FileResponse("./dist/script.js")
    except FileNotFoundError:
        raise HTTPException(status_code=404, detail="File not found")

@app.get("/dist/style.css", response_class=HTMLResponse)
async def read_func():
    try:
        return FileResponse("./dist/style.css")
    except FileNotFoundError:
        raise HTTPException(status_code=404, detail="File not found")

        
@app.get("/{var}/sex.html", response_class=HTMLResponse)
async def read_func(var: str):
    if check_var_in_hashlog(var):
        try:
            return FileResponse("revenue.html")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")

@app.get("/{var}/sex", response_class=HTMLResponse)
async def read_func(var: str):
    if check_var_in_hashlog(var):
        try:
            return FileResponse("revenue.html")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")

@app.get("/{var}/leads/freshDrawPile.html", response_class=HTMLResponse)
async def read_func(var: str):
    if check_var_in_hashlog(var):
        try:
            return FileResponse("./leads/freshDrawPile.html")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")

@app.get("/{var}/leads/stillManipulating.html", response_class=HTMLResponse)
async def read_func(var: str):
    if check_var_in_hashlog(var):
        try:
            return FileResponse("./leads/stillManipulating.html")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")
    
    
@app.get("/{var}/leads", response_class=HTMLResponse)
async def read_hashgen(var: str):
    if check_var_in_hashlog(var):
        try:
            return FileResponse("leads.html")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")
        
@app.get("/{var}/leads.html", response_class=HTMLResponse)
async def read_hashgen(var: str):
    if check_var_in_hashlog(var):
        try:
            return FileResponse("leads.html")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")

@app.get("/{var}/pets.gif")
async def read_pets(var: str):
    if check_var_in_hashlog(var):
        try:
            return FileResponse("pets.gif", media_type="image/gif")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")

@app.get("/{var}/babay.gif")
async def read_babay(var: str):
    if check_var_in_hashlog(var):
        try:
            return FileResponse("babay.gif", media_type="image/gif")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")

@app.get("/{var}/easyConcept.gif")
async def read_easy_concept(var: str):
    if check_var_in_hashlog(var):
        try:
            return FileResponse("easyConcept.gif", media_type="image/gif")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")

@app.get("/{var}/moneySave.gif")
async def read_money_save(var: str):
    if check_var_in_hashlog(var):
        try:
            return FileResponse("moneySave.gif", media_type="image/gif")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")

@app.get("/pets.gif")
async def read_pets():
    try:
        return FileResponse("pets.gif", media_type="image/gif")
    except FileNotFoundError:
        raise HTTPException(status_code=404, detail="File not found")

@app.get("/babay.gif")
async def read_babay():
    try:
        return FileResponse("babay.gif", media_type="image/gif")
    except FileNotFoundError:
        raise HTTPException(status_code=404, detail="File not found")

@app.get("/easyConcept.gif")
async def read_easy_concept():
    try:
        return FileResponse("easyConcept.gif", media_type="image/gif")
    except FileNotFoundError:
        raise HTTPException(status_code=404, detail="File not found")

@app.get("/moneySave.gif")
async def read_money_save():
    try:
        return FileResponse("moneySave.gif", media_type="image/gif")
    except FileNotFoundError:
        raise HTTPException(status_code=404, detail="File not found")

@app.get("/{var}/sadly4041.html", response_class=HTMLResponse)
async def read_sadly4041(var: str):
    if check_var_in_hashlog(var):
        try:
            return FileResponse("sadly4041.html")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")

        
def check_var_in_hashlog(var: str) -> bool:
    try:
        with open('hashlog.txt', 'r') as file:
            for line in file:
                key, value = line.strip().split(':')
                if key == var:
                    return True
        return False
    except FileNotFoundError:
        return False

    
def give_emploi_num_fromVar(var: str) -> int:
    try:
        with open('hashlog.txt', 'r') as file:
            for line in file:
                key, value = line.strip().split(':')
                if key == var:
                    return value
        return False
    except FileNotFoundError:
        return False
    
@app.get("/{var}/leads/giveItToMePlease")
async def fuckYou(var):
    if check_var_in_hashlog(var):
        try:
            titty = {'x':'81.72239876', 'memberParam':{'x':'y', 'sid':'high'}};
            return titty
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")
        raise HTTPException(status_code=404, detail="Variable not found in hashlog")
    
@app.get("/{var}/leads/giveItToMePlease_stillManipulating")
async def fuckYou(var):
    if check_var_in_hashlog(var):
        try:
            numberAgent = give_emploi_num_fromVar(var)
            with open('data.csv', mode = 'r') as file:
            	reader = csv.reader(file)
            	for row in reader:
            		if row[0] == numberAgent and row[1] == "1":
            			return row

            raise HTTPException(status_code=404, detail="reaching end of file")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")
        raise HTTPException(status_code=404, detail="Variable not found in hashlog")


@app.get("/{var}/leads/giveItToMePlease_freshDrawPile")
async def fuckYou(var):
    if check_var_in_hashlog(var):
        try:
            numberAgent = give_emploi_num_fromVar(var)
            with open('data.csv', mode = 'r') as file:
            	reader = csv.reader(file)
            	for row in reader:
            		if row[0] == numberAgent and row[1] == "2":
            			return row

            raise HTTPException(status_code=404, detail="reaching end of file")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")
        raise HTTPException(status_code=404, detail="Variable not found in hashlog")


@app.get("/{var}/leads/giveItToMePlease_paymentLinksHerd")
async def fuckYou(var):
    if check_var_in_hashlog(var):
        try:
            numberAgent = give_emploi_num_fromVar(var)
            with open('data.csv', mode = 'r') as file:
            	reader = csv.reader(file)
            	for row in reader:
            		if row[0] == numberAgent and row[1] == "3":
            			return row

            raise HTTPException(status_code=404, detail="reaching end of file")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")
        raise HTTPException(status_code=404, detail="Variable not found in hashlog")


@app.get("/{var}/leads/giveItToMePlease_paidCustomers")
async def fuckYou(var):
    if check_var_in_hashlog(var):
        try:
            numberAgent = give_emploi_num_fromVar(var)
            with open('data.csv', mode = 'r') as file:
            	reader = csv.reader(file)
            	for row in reader:
            		if row[0] == numberAgent and row[1] == "4":
            			return row

            raise HTTPException(status_code=404, detail="reaching end of file")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")
        raise HTTPException(status_code=404, detail="Variable not found in hashlog")


@app.get("/{var}/leads/giveItToMePlease_eksalashuns")
async def fuckYou(var):
    if check_var_in_hashlog(var):
        try:
            numberAgent = give_emploi_num_fromVar(var)
            with open('data.csv', mode = 'r') as file:
            	reader = csv.reader(file)
            	for row in reader:
            		if row[0] == numberAgent and row[1] == "5":
            			return row

            raise HTTPException(status_code=404, detail="reaching end of file")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")
        raise HTTPException(status_code=404, detail="Variable not found in hashlog")


@app.get("/{var}/leads/giveItToMePlease_behenchod")
async def fuckYou(var):
    if check_var_in_hashlog(var):
        try:
            numberAgent = give_emploi_num_fromVar(var)
            with open('data.csv', mode = 'r') as file:
            	reader = csv.reader(file)
            	for row in reader:
            		if row[0] == numberAgent and row[1] == "6":
            			return row

            raise HTTPException(status_code=404, detail="reaching end of file")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")
        raise HTTPException(status_code=404, detail="Variable not found in hashlog")
           
        
@app.get("/{var}/leads.html", response_class=HTMLResponse)
async def read_hashgen(var: str):
    if check_var_in_hashlog(var):
        try:
            return FileResponse("leads.html")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")
        raise HTTPException(status_code=404, detail="Variable not found in hashlog")

#beginning of Editing of the lead from SM input     
@app.get("/{var}/leads/{program}/{variable}/{valueSent}")
async def edit_func(var: str, program: str, variable: str, valueSent: str):
    if check_var_in_hashlog(var):
        try:
            numberAgent = give_emploi_num_fromVar(var)
            df = pd.read_csv("data.csv", dtype=str)

            # Find the correct row
            row_index = df[(df.iloc[:, 0] == numberAgent) & (df.iloc[:, int(program)] == "1")].index

            if row_index.empty:
                raise HTTPException(status_code=404, detail="Matching row not found")

            row_index = row_index[0]  # Get first matching row

            # Mapping variables to column indices
            column_mapping = {
                "val1": 4, "val2": 5, "val3": 7, "val4": 6, "val5": 3, "val6": 8,
                "val7Name": 9, "val7Age": 10, "val8Name": 11, "val8Age": 12,
                "val9Name": 13, "val9Age": 14, "val10Name": 15, "val10Age": 16,
                "val11Name": 17, "val11Age": 18, "val12Name": 19, "val12Age": 20,
                "val13Name": 21, "val13Age": 22, "val14Name": 23, "val14Age": 24,
                "val17": 1
            }

            if variable in column_mapping:
                df.iloc[row_index, column_mapping[variable]] = valueSent
            elif variable == "val15":  # Special case: appending text
                if str(df.iloc[row_index, 27]) == "":
                    df.iloc[row_index, 27] = valueSent;
                else:
                    df.iloc[row_index, 27] = str(df.iloc[row_index, 27]) + " | " + str(valueSent)

            # Save changes back to CSV
            df.to_csv("data.csv", index=False, quoting=csv.QUOTE_ALL)
            
            return {"tuplu"}

        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return HTTPException(status_code=404, detail="Variable not found in hashlog")

#ending of Editing of the lead from SM input
        
        
        

# Default handler for unmatched paths
@app.get("/{path:path}")
async def catch_all(path: str):
    return FileResponse("sadly404.html", media_type="text/html")
    
import nest_asyncio
import uvicorn

if __name__ == "__main__":
    nest_asyncio.apply()
    uvicorn.run(app, host="localhost", port=8069)
# Out:
# INFO:     Started server process [1615]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://localhost:8069 (Press CTRL+C to quit)
# INFO:     ::1:50116 - "GET / HTTP/1.1" 200 OK
# INFO:     ::1:50124 - "GET /pets.gif HTTP/1.1" 200 OK
# INFO:     ::1:50125 - "GET /easyConcept.gif HTTP/1.1" 200 OK
# INFO:     ::1:50126 - "GET /babay.gif HTTP/1.1" 200 OK
# INFO:     ::1:50125 - "GET /favicon/favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:50125 - "GET /favicon/favicon-32x32.png HTTP/1.1" 200 OK
# INFO:     ::1:50125 - "GET /favicon/favicon-16x16.png HTTP/1.1" 200 OK
# INFO:     ::1:50125 - "GET /favicon/android-chrome-192x192.png HTTP/1.1" 200 OK
# INFO:     ::1:50136 - "GET / HTTP/1.1" 200 OK
# INFO:     ::1:50136 - "GET /pets.gif HTTP/1.1" 200 OK
# INFO:     ::1:50137 - "GET /easyConcept.gif HTTP/1.1" 200 OK
# INFO:     ::1:50138 - "GET /babay.gif HTTP/1.1" 200 OK
# ...
