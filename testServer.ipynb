# %%
from fastapi import FastAPI, HTTPException
from fastapi.responses import FileResponse, HTMLResponse
import csv

app = FastAPI()

@app.get("/", response_class=HTMLResponse)
async def read_root():
    try:
        return FileResponse("index.html")
    except FileNotFoundError:
        raise HTTPException(status_code=404, detail="File not found")

@app.get("/sex", response_class=HTMLResponse)
async def read_func():
    try:
        return FileResponse("revenue.html")
    except FileNotFoundError:
        raise HTTPException(status_code=404, detail="File not found")

@app.get("/{var}/sex.html", response_class=HTMLResponse)
async def read_func(var: str):
    if check_var_in_hashlog(var):
        try:
            return FileResponse("revenue.html")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")

@app.get("/{var}/sex", response_class=HTMLResponse)
async def read_func(var: str):
    if check_var_in_hashlog(var):
        try:
            return FileResponse("revenue.html")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")

@app.get("/{var}/leads/freshDrawPile.html", response_class=HTMLResponse)
async def read_func(var: str):
    if check_var_in_hashlog(var):
        try:
            return FileResponse("./leads/freshDrawPile.html")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")

@app.get("/{var}/leads/stillManipulating.html", response_class=HTMLResponse)
async def read_func(var: str):
    if check_var_in_hashlog(var):
        try:
            return FileResponse("./leads/stillManipulating.html")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")
    
    
@app.get("/{var}/leads", response_class=HTMLResponse)
async def read_hashgen(var: str):
    if check_var_in_hashlog(var):
        try:
            return FileResponse("leads.html")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")
        
@app.get("/{var}/leads.html", response_class=HTMLResponse)
async def read_hashgen(var: str):
    if check_var_in_hashlog(var):
        try:
            return FileResponse("leads.html")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")

@app.get("/{var}/pets.gif")
async def read_pets(var: str):
    if check_var_in_hashlog(var):
        try:
            return FileResponse("pets.gif", media_type="image/gif")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")

@app.get("/{var}/babay.gif")
async def read_babay(var: str):
    if check_var_in_hashlog(var):
        try:
            return FileResponse("babay.gif", media_type="image/gif")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")

@app.get("/{var}/easyConcept.gif")
async def read_easy_concept(var: str):
    if check_var_in_hashlog(var):
        try:
            return FileResponse("easyConcept.gif", media_type="image/gif")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")

@app.get("/{var}/moneySave.gif")
async def read_money_save(var: str):
    if check_var_in_hashlog(var):
        try:
            return FileResponse("moneySave.gif", media_type="image/gif")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")

@app.get("/pets.gif")
async def read_pets():
    try:
        return FileResponse("pets.gif", media_type="image/gif")
    except FileNotFoundError:
        raise HTTPException(status_code=404, detail="File not found")

@app.get("/babay.gif")
async def read_babay():
    try:
        return FileResponse("babay.gif", media_type="image/gif")
    except FileNotFoundError:
        raise HTTPException(status_code=404, detail="File not found")

@app.get("/easyConcept.gif")
async def read_easy_concept():
    try:
        return FileResponse("easyConcept.gif", media_type="image/gif")
    except FileNotFoundError:
        raise HTTPException(status_code=404, detail="File not found")

@app.get("/moneySave.gif")
async def read_money_save():
    try:
        return FileResponse("moneySave.gif", media_type="image/gif")
    except FileNotFoundError:
        raise HTTPException(status_code=404, detail="File not found")

@app.get("/{var}/sadly4041.html", response_class=HTMLResponse)
async def read_sadly4041(var: str):
    if check_var_in_hashlog(var):
        try:
            return FileResponse("sadly4041.html")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")

        
def check_var_in_hashlog(var: str) -> bool:
    try:
        with open('hashlog.txt', 'r') as file:
            for line in file:
                key, value = line.strip().split(':')
                if key == var:
                    return True
        return False
    except FileNotFoundError:
        return False

    
def give_emploi_num_fromVar(var: str) -> int:
    try:
        with open('hashlog.txt', 'r') as file:
            for line in file:
                key, value = line.strip().split(':')
                if key == var:
                    return value
        return False
    except FileNotFoundError:
        return False
    
@app.get("/{var}/leads/giveItToMePlease")
async def fuckYou(var):
    if check_var_in_hashlog(var):
        try:
            titty = {'x':'81.72239876', 'memberParam':{'x':'y', 'sid':'high'}};
            return titty
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")
        raise HTTPException(status_code=404, detail="Variable not found in hashlog")
    
@app.get("/{var}/leads/giveItToMePlease_stillManipulating")
async def fuckYou(var):
    if check_var_in_hashlog(var):
        try:
            numberAgent = give_emploi_num_fromVar(var)
            with open('data.csv', mode = 'r') as file:
            	reader = csv.reader(file)
            	for row in reader:
            		if row[0] == numberAgent and row[1] == "1":
            			return row

            raise HTTPException(status_code=404, detail="reaching end of file")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")
        raise HTTPException(status_code=404, detail="Variable not found in hashlog")


@app.get("/{var}/leads/giveItToMePlease_freshDrawPile")
async def fuckYou(var):
    if check_var_in_hashlog(var):
        try:
            numberAgent = give_emploi_num_fromVar(var)
            with open('data.csv', mode = 'r') as file:
            	reader = csv.reader(file)
            	for row in reader:
            		if row[0] == numberAgent and row[1] == "2":
            			return row

            raise HTTPException(status_code=404, detail="reaching end of file")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")
        raise HTTPException(status_code=404, detail="Variable not found in hashlog")


@app.get("/{var}/leads/giveItToMePlease_paymentLinksHerd")
async def fuckYou(var):
    if check_var_in_hashlog(var):
        try:
            numberAgent = give_emploi_num_fromVar(var)
            with open('data.csv', mode = 'r') as file:
            	reader = csv.reader(file)
            	for row in reader:
            		if row[0] == numberAgent and row[1] == "3":
            			return row

            raise HTTPException(status_code=404, detail="reaching end of file")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")
        raise HTTPException(status_code=404, detail="Variable not found in hashlog")


@app.get("/{var}/leads/giveItToMePlease_paidCustomers")
async def fuckYou(var):
    if check_var_in_hashlog(var):
        try:
            numberAgent = give_emploi_num_fromVar(var)
            with open('data.csv', mode = 'r') as file:
            	reader = csv.reader(file)
            	for row in reader:
            		if row[0] == numberAgent and row[1] == "4":
            			return row

            raise HTTPException(status_code=404, detail="reaching end of file")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")
        raise HTTPException(status_code=404, detail="Variable not found in hashlog")


@app.get("/{var}/leads/giveItToMePlease_eksalashuns")
async def fuckYou(var):
    if check_var_in_hashlog(var):
        try:
            numberAgent = give_emploi_num_fromVar(var)
            with open('data.csv', mode = 'r') as file:
            	reader = csv.reader(file)
            	for row in reader:
            		if row[0] == numberAgent and row[1] == "5":
            			return row

            raise HTTPException(status_code=404, detail="reaching end of file")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")
        raise HTTPException(status_code=404, detail="Variable not found in hashlog")


@app.get("/{var}/leads/giveItToMePlease_behenchod")
async def fuckYou(var):
    if check_var_in_hashlog(var):
        try:
            numberAgent = give_emploi_num_fromVar(var)
            with open('data.csv', mode = 'r') as file:
            	reader = csv.reader(file)
            	for row in reader:
            		if row[0] == numberAgent and row[1] == "6":
            			return row

            raise HTTPException(status_code=404, detail="reaching end of file")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")
        raise HTTPException(status_code=404, detail="Variable not found in hashlog")
           
        
@app.get("/{var}/leads.html", response_class=HTMLResponse)
async def read_hashgen(var: str):
    if check_var_in_hashlog(var):
        try:
            return FileResponse("leads.html")
        except FileNotFoundError:
            raise HTTPException(status_code=404, detail="File not found")
    else:
        return FileResponse("sadly404.html", media_type="text/html")
        raise HTTPException(status_code=404, detail="Variable not found in hashlog")

#beginning of Editing of the lead from SM input     
@app.get("/{var}/corrupt")
#ending of Editing of the lead from SM input
        
        
        

# Default handler for unmatched paths
@app.get("/{path:path}")
async def catch_all(path: str):
    return FileResponse("sadly404.html", media_type="text/html")
    
import nest_asyncio
import uvicorn

if __name__ == "__main__":
    nest_asyncio.apply()
    uvicorn.run(app, host="localhost", port=8069)
# Out:
# INFO:     Started server process [1624]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://localhost:8069 (Press CTRL+C to quit)
# INFO:     ::1:50101 - "GET /pets.gif HTTP/1.1" 200 OK
# INFO:     ::1:50102 - "GET /babay.gif HTTP/1.1" 200 OK
# INFO:     ::1:50103 - "GET /easyConcept.gif HTTP/1.1" 200 OK
# INFO:     ::1:50112 - "GET /favicon/favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:50114 - "GET /favicon/site.webmanifest HTTP/1.1" 200 OK
# INFO:     ::1:50115 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:50115 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:50537 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:50537 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:50559 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:50559 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:50559 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:51008 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:51008 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:51008 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:51747 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:51747 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:51747 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:54377 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:54377 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:54377 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:61398 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:61398 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:61398 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:61398 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:61398 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:61398 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:61592 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:61592 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:61592 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:61941 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:61941 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:61941 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:61989 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:61989 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:61989 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:62211 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:62211 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:62211 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:62339 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:62339 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:62339 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:63212 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:63212 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:63212 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:49904 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:49904 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:49904 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:49966 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:49966 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:49966 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:50265 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:50265 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:50265 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:51684 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:51684 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:51684 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:51916 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:51916 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:51916 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:52132 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:52132 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:52132 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:52631 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:52631 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:52631 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:53042 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:53042 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:53042 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:53378 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:53378 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:53378 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:53378 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:53378 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:53378 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:53789 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:53789 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:53789 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:62265 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:62265 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:62265 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:62319 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:62319 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:62319 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:62655 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:62655 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:62655 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:62978 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:62978 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:62978 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:63738 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:63738 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:63738 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:63903 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:63903 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:63903 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:64116 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:64116 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:64116 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:64285 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:64285 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:64285 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:64713 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:64713 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:64713 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:65172 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:65172 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:65172 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:65429 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:65429 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:65429 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:49330 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:49330 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:49330 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:49330 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:49330 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:49330 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:49534 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:49534 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:49534 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:49899 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:49899 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:49899 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:50081 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:50081 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:50081 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:50396 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:50396 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:50396 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:50597 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:50597 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:50597 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:50702 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:50702 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:50702 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:51073 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:51073 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:51073 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:51302 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:51302 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:51302 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:51551 - "GET /QjBnV0g/leads/stillManipulating.html HTTP/1.1" 200 OK
# INFO:     ::1:51551 - "GET /favicon.ico HTTP/1.1" 200 OK
# INFO:     ::1:51551 - "GET /QjBnV0g/leads/giveItToMePlease_stillManipulating HTTP/1.1" 200 OK
# INFO:     ::1:51592 - "GET /QjBnV0g/leads/1/val5/val5%20%3A%203 HTTP/1.1" 200 OK
# INFO:     ::1:51852 - "GET /QjBnV0g/leads/1/val5/val5%20%3A%203 HTTP/1.1" 200 OK
# INFO:     ::1:51853 - "GET /QjBnV0g/leads/1/val4/val4%20%3A%20sadfasdf HTTP/1.1" 200 OK
